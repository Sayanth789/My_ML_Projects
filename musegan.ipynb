# %% [markdown]
# # 🎶 Music Generation - MuseGAN

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own MuseGAN model to generate music in the style of the Bach chorales

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-colorblind")

import os
import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    optimizers,
    callbacks,
    initializers,
    metrics,
)

from musegan_utils import notes_to_midi, draw_score

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
BATCH_SIZE = 64

N_BARS = 2
N_STEPS_PER_BAR = 16
MAX_PITCH = 83
N_PITCHES = MAX_PITCH + 1
Z_DIM = 32


CRITIC_STEPS = 5
GP_WEIGHT = 10
CRITIC_LEARNING_RATE = 0.001
GENERATOR_LEARNING_RATE = 0.001
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
EPOCHS = 6000
LOAD_MODEL = False

# %% [markdown]
# ## 1. Prepare the Data

# %%
# Load the data
file = os.path.join("./data//Jsb16thSeparated.npz")
with np.load(file, encoding="bytes", allow_pickle=True) as f:
    data = f["train"]

# %%
N_SONGS = len(data)
print(f"{N_SONGS} chorales in the dataset")
chorale = data[0]
N_BEATS, N_TRACKS = chorale.shape
print(f"{N_BEATS, N_TRACKS} shape of chorale 0")
print("\nChorale 0")
print(chorale[:8])
# Out:
# 229 chorales in the dataset
# (192, 4) shape of chorale 0
#
# Chorale 0
# [[74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [75. 70. 58. 55.]
#  [75. 70. 58. 55.]
#  [75. 70. 60. 55.]
#  [75. 70. 60. 55.]]

# %%
two_bars = np.array([x[: (N_STEPS_PER_BAR * N_BARS)] for x in data])
two_bars = np.array(np.nan_to_num(two_bars, nan=MAX_PITCH), dtype=int)
two_bars = two_bars.reshape([N_SONGS, N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"Two bars shape {two_bars.shape}")
# Out:
# Two bars shape (229, 2, 16, 4)

# %%
data_binary = np.eye(N_PITCHES)[two_bars]
data_binary[data_binary == 0] = -1
data_binary = data_binary.transpose([0, 1, 2, 4, 3])
print(f"Data binary shape {data_binary.shape}")
# Out:
# Data binary shape (229, 2, 16, 84, 4)

# %% [markdown]
# ## 2. Build the GAN <a name="build"></a>

# %%
# Some helper functions

initializer = initializers.RandomNormal(mean=0.0, stddev=0.02)


def conv(x, f, k, s, p):
    x = layers.Conv3D(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    x = layers.LeakyReLU()(x)
    return x


def conv_t(x, f, k, s, a, p, bn):
    x = layers.Conv2DTranspose(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    if bn:
        x = layers.BatchNormalization(momentum=0.9)(x)

    x = layers.Activation(a)(x)
    return x

# %%
def TemporalNetwork():
    input_layer = layers.Input(shape=(Z_DIM,), name="temporal_input")
    x = layers.Reshape([1, 1, Z_DIM])(input_layer)
    x = conv_t(x, f=1024, k=(2, 1), s=(1, 1), a="relu", p="valid", bn=True)
    x = conv_t(
        x, f=Z_DIM, k=(N_BARS - 1, 1), s=(1, 1), a="relu", p="valid", bn=True
    )
    output_layer = layers.Reshape([N_BARS, Z_DIM])(x)
    return models.Model(input_layer, output_layer)


TemporalNetwork().summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ temporal_input (InputLayer)     │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 1, 1024)     │        66,560 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2, 1, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 2, 1, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 2, 1, 32)       │        32,800 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2, 1, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 2, 1, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 2, 32)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 103,584 (404.62 KB)
#  Trainable params: 101,472 (396.38 KB)
#  Non-trainable params: 2,112 (8.25 KB)

# %%
def BarGenerator():
    input_layer = layers.Input(shape=(Z_DIM * 4,), name="bar_generator_input")

    x = layers.Dense(1024)(input_layer)
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.Activation("relu")(x)
    x = layers.Reshape([2, 1, 512])(x)

    x = conv_t(x, f=512, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(1, 7), s=(1, 7), a="relu", p="same", bn=True)
    x = conv_t(x, f=1, k=(1, 12), s=(1, 12), a="tanh", p="same", bn=False)

    output_layer = layers.Reshape([1, N_STEPS_PER_BAR, N_PITCHES, 1])(x)

    return models.Model(input_layer, output_layer)


BarGenerator().summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bar_generator_input             │ (None, 128)            │             0 │
# │ (InputLayer)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       132,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 2, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 4, 1, 512)      │       524,800 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 1, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 4, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 8, 1, 256)      │       262,400 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 1, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 8, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 16, 1, 256)     │       131,328 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 1, 256)     │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 16, 1, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 16, 7, 256)     │       459,008 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 16, 7, 256)     │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 16, 7, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 16, 84, 1)      │         3,073 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 16, 84, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 16, 84, 1)   │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,521,921 (5.81 MB)
#  Trainable params: 1,517,313 (5.79 MB)
#  Non-trainable params: 4,608 (18.00 KB)

# %%
def Generator():
    chords_input = layers.Input(shape=(Z_DIM,), name="chords_input")
    style_input = layers.Input(shape=(Z_DIM,), name="style_input")
    melody_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="melody_input")
    groove_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="groove_input")

    # CHORDS -> TEMPORAL NETWORK
    chords_tempNetwork = TemporalNetwork()
    chords_over_time = chords_tempNetwork(chords_input)  # [n_bars, z_dim]

    # MELODY -> TEMPORAL NETWORK
    melody_over_time = [
        None
    ] * N_TRACKS  # list of n_tracks [n_bars, z_dim] tensors
    melody_tempNetwork = [None] * N_TRACKS
    for track in range(N_TRACKS):
        melody_tempNetwork[track] = TemporalNetwork()
        melody_track = layers.Lambda(lambda x, track=track: x[:, track, :])(
            melody_input
        )
        melody_over_time[track] = melody_tempNetwork[track](melody_track)

    # CREATE BAR GENERATOR FOR EACH TRACK
    barGen = [None] * N_TRACKS
    for track in range(N_TRACKS):
        barGen[track] = BarGenerator()

    # CREATE OUTPUT FOR EVERY TRACK AND BAR
    bars_output = [None] * N_BARS
    c = [None] * N_BARS
    for bar in range(N_BARS):
        track_output = [None] * N_TRACKS

        c[bar] = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
            chords_over_time
        )  # [z_dim]
        s = style_input  # [z_dim]

        for track in range(N_TRACKS):
            m = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
                melody_over_time[track]
            )  # [z_dim]
            g = layers.Lambda(lambda x, track=track: x[:, track, :])(
                groove_input
            )  # [z_dim]

            z_input = layers.Concatenate(
                axis=1, name="total_input_bar_{}_track_{}".format(bar, track)
            )([c[bar], s, m, g])

            track_output[track] = barGen[track](z_input)

        bars_output[bar] = layers.Concatenate(axis=-1)(track_output)

    generator_output = layers.Concatenate(axis=1, name="concat_bars")(
        bars_output
    )

    return models.Model(
        [chords_input, style_input, melody_input, groove_input],
        generator_output,
    )


generator = Generator()
# generator.summary()

# %%
def Critic():
    critic_input = layers.Input(
        shape=(N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS),
        name="critic_input",
    )

    x = critic_input

    x = conv(x, f=128, k=(2, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(N_BARS - 1, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(1, 1, 12), s=(1, 1, 12), p="same")
    x = conv(x, f=128, k=(1, 1, 7), s=(1, 1, 7), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=256, k=(1, 4, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=512, k=(1, 3, 1), s=(1, 2, 1), p="same")

    x = layers.Flatten()(x)

    x = layers.Dense(1024, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)

    critic_output = layers.Dense(
        1, activation=None, kernel_initializer=initializer
    )(x)

    return models.Model(critic_input, critic_output)


critic = Critic()
# critic.summary()

# %%
class MuseGAN(models.Model):
    def __init__(self, critic, generator, latent_dim, critic_steps, gp_weight):
        super(MuseGAN, self).__init__()
        self.critic = critic
        self.generator = generator
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight

    def compile(self, c_optimizer, g_optimizer):
        super(MuseGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        self.c_wass_loss_metric = metrics.Mean(name="c_wass_loss")
        self.c_gp_metric = metrics.Mean(name="c_gp")
        self.c_loss_metric = metrics.Mean(name="c_loss")
        self.g_loss_metric = metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [
            self.c_loss_metric,
            self.c_wass_loss_metric,
            self.c_gp_metric,
            self.g_loss_metric,
        ]

    def gradient_penalty(self, batch_size, real_images, fake_images):
        alpha = tf.random.normal([batch_size, 1, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            pred = self.critic(interpolated, training=True)

        grads = gp_tape.gradient(pred, [interpolated])[0]
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        for i in range(self.critic_steps):
            chords_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            style_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            melody_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )
            groove_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )

            random_latent_vectors = [
                chords_random_latent_vectors,
                style_random_latent_vectors,
                melody_random_latent_vectors,
                groove_random_latent_vectors,
            ]

            with tf.GradientTape() as tape:
                fake_images = self.generator(
                    random_latent_vectors, training=True
                )
                fake_predictions = self.critic(fake_images, training=True)
                real_predictions = self.critic(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(
                    real_predictions
                )
                c_gp = self.gradient_penalty(
                    batch_size, real_images, fake_images
                )
                c_loss = c_wass_loss + c_gp * self.gp_weight

            c_gradient = tape.gradient(c_loss, self.critic.trainable_variables)
            self.c_optimizer.apply_gradients(
                zip(c_gradient, self.critic.trainable_variables)
            )

        chords_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )

        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]

        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_predictions = self.critic(fake_images, training=True)
            g_loss = -tf.reduce_mean(fake_predictions)

        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        self.c_loss_metric.update_state(c_loss)
        self.c_wass_loss_metric.update_state(c_wass_loss)
        self.c_gp_metric.update_state(c_gp)
        self.g_loss_metric.update_state(g_loss)

        return {m.name: m.result() for m in self.metrics}

    def generate_piano_roll(self, num_scores):
        chords_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]
        generated_music = self.generator(random_latent_vectors)
        generated_music = generated_music.numpy()
        return generated_music

# %%
# Create a MuseGAN
musegan = MuseGAN(
    critic=critic,
    generator=generator,
    latent_dim=Z_DIM,
    critic_steps=CRITIC_STEPS,
    gp_weight=GP_WEIGHT,
)

# %%
if LOAD_MODEL:
    musegan.load_weights("./checkpoint/checkpoint.ckpt")

# %% [markdown]
# ## 3. Train the MuseGAN <a name="train"></a>

# %%
# Compile the GAN
musegan.compile(
    c_optimizer=optimizers.Adam(
        learning_rate=CRITIC_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
    g_optimizer=optimizers.Adam(
        learning_rate=GENERATOR_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
)

# %%
musegan.build(
    input_shape=(None, N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS)
)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class MusicGenerator(callbacks.Callback):
    def __init__(self, num_scores):
        self.num_scores = num_scores

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 1 == 0:
            generated_music = self.model.generate_piano_roll(self.num_scores)
            notes_to_midi(
                generated_music,
                N_BARS,
                N_TRACKS,
                N_STEPS_PER_BAR,
                filename="output_" + str(epoch).zfill(4),
            )
            # display(generated_images, save_to = "./output/generated_img_%03d.png" % (epoch), cmap = None)


music_generator_callback = MusicGenerator(1)

# %%
history = musegan.fit(
    data_binary,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        music_generator_callback,
    ],
)
# Out:
# Streaming output truncated to the last 5000 lines.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 4.1468 - c_loss: -57.7133 - c_wass_loss: -99.1812 - g_loss: 27.7766
# Epoch 3267/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.3017 - c_loss: -67.9250 - c_wass_loss: -100.9418 - g_loss: 2.5407
# Epoch 3268/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.9190 - c_loss: -65.9065 - c_wass_loss: -95.0968 - g_loss: -8.4322
# Epoch 3269/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.7865 - c_loss: -59.2448 - c_wass_loss: -97.1101 - g_loss: 13.0917
# Epoch 3270/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 533ms/step - c_gp: 2.9719 - c_loss: -64.3524 - c_wass_loss: -94.0710 - g_loss: 12.2616
# Epoch 3271/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.3509 - c_loss: -61.7979 - c_wass_loss: -95.3064 - g_loss: -0.0670
# Epoch 3272/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.2314 - c_loss: -69.1167 - c_wass_loss: -101.4304 - g_loss: 3.7159
# Epoch 3273/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 547ms/step - c_gp: 3.1293 - c_loss: -61.1548 - c_wass_loss: -92.4480 - g_loss: 4.1371
# Epoch 3274/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 3.0033 - c_loss: -66.9455 - c_wass_loss: -96.9782 - g_loss: 12.1661
# Epoch 3275/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 6.8403 - c_loss: -49.0871 - c_wass_loss: -117.4904 - g_loss: 21.1907
# Epoch 3276/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 4.1575 - c_loss: -49.9276 - c_wass_loss: -91.5028 - g_loss: 15.3407
# Epoch 3277/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.3575 - c_loss: -61.9638 - c_wass_loss: -95.5386 - g_loss: -4.2541
# Epoch 3278/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 6.5948 - c_loss: -35.5010 - c_wass_loss: -101.4487 - g_loss: 15.4221
# Epoch 3279/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 561ms/step - c_gp: 2.6180 - c_loss: -57.1942 - c_wass_loss: -83.3746 - g_loss: -12.0380
# Epoch 3280/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.7135 - c_loss: -66.1815 - c_wass_loss: -93.3165 - g_loss: 15.9078
# Epoch 3281/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.6419 - c_loss: -64.0846 - c_wass_loss: -100.5039 - g_loss: 3.5650
# Epoch 3282/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - c_gp: 3.8331 - c_loss: -61.0713 - c_wass_loss: -99.4026 - g_loss: -7.7544
# Epoch 3283/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.6741 - c_loss: -58.7505 - c_wass_loss: -95.4914 - g_loss: -8.6250
# Epoch 3284/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.5520 - c_loss: -54.4589 - c_wass_loss: -89.9788 - g_loss: -9.3218
# Epoch 3285/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - c_gp: 2.8294 - c_loss: -64.9892 - c_wass_loss: -93.2833 - g_loss: 13.2162
# Epoch 3286/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.6516 - c_loss: -56.7747 - c_wass_loss: -93.2904 - g_loss: 19.6178
# Epoch 3287/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.4849 - c_loss: -52.7468 - c_wass_loss: -97.5955 - g_loss: -8.2429
# Epoch 3288/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 2.7124 - c_loss: -61.8797 - c_wass_loss: -89.0038 - g_loss: 2.3620
# Epoch 3289/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1459 - c_loss: -61.6051 - c_wass_loss: -93.0643 - g_loss: -13.3044
# Epoch 3290/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.7411 - c_loss: -68.6928 - c_wass_loss: -96.1042 - g_loss: 0.2720
# Epoch 3291/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 534ms/step - c_gp: 4.0686 - c_loss: -55.7822 - c_wass_loss: -96.4686 - g_loss: -26.6974
# Epoch 3292/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1656 - c_loss: -60.1413 - c_wass_loss: -91.7973 - g_loss: -3.3364
# Epoch 3293/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.6713 - c_loss: -56.1137 - c_wass_loss: -92.8268 - g_loss: -6.1823
# Epoch 3294/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.3011 - c_loss: -63.3300 - c_wass_loss: -96.3411 - g_loss: 1.0517
# Epoch 3295/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.0079 - c_loss: -61.8924 - c_wass_loss: -91.9713 - g_loss: 7.8513
# Epoch 3296/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.7663 - c_loss: -67.4581 - c_wass_loss: -95.1208 - g_loss: -3.4937
# Epoch 3297/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 536ms/step - c_gp: 3.1894 - c_loss: -64.8934 - c_wass_loss: -96.7875 - g_loss: -22.1296
# Epoch 3298/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.7231 - c_loss: -56.2360 - c_wass_loss: -93.4673 - g_loss: -16.7187
# Epoch 3299/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.4694 - c_loss: -62.2394 - c_wass_loss: -96.9335 - g_loss: -6.6552
# Epoch 3300/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.6354 - c_loss: -60.7681 - c_wass_loss: -97.1218 - g_loss: -2.8142
# Epoch 3301/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 3.6978 - c_loss: -57.8994 - c_wass_loss: -94.8776 - g_loss: -11.2553
# Epoch 3302/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.9811 - c_loss: -60.6087 - c_wass_loss: -100.4193 - g_loss: 11.2420
# Epoch 3303/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 5.8690 - c_loss: -40.8406 - c_wass_loss: -99.5306 - g_loss: 18.9313
# Epoch 3304/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5409 - c_loss: -62.2679 - c_wass_loss: -87.6770 - g_loss: 1.5034
# Epoch 3305/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.4209 - c_loss: -57.7104 - c_wass_loss: -101.9198 - g_loss: 5.3545
# Epoch 3306/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.3283 - c_loss: -55.7896 - c_wass_loss: -89.0725 - g_loss: 3.8713
# Epoch 3307/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.2845 - c_loss: -70.4438 - c_wass_loss: -103.2887 - g_loss: 22.9750
# Epoch 3308/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 4.3827 - c_loss: -52.2622 - c_wass_loss: -96.0890 - g_loss: 15.6439
# Epoch 3309/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 548ms/step - c_gp: 3.2688 - c_loss: -58.8744 - c_wass_loss: -91.5621 - g_loss: 1.6482
# Epoch 3310/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.3993 - c_loss: -57.0524 - c_wass_loss: -91.0459 - g_loss: 9.2649
# Epoch 3311/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.1573 - c_loss: -61.7059 - c_wass_loss: -93.2785 - g_loss: -12.4837
# Epoch 3312/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.7084 - c_loss: -61.2678 - c_wass_loss: -98.3518 - g_loss: -0.0320
# Epoch 3313/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.0107 - c_loss: -59.6815 - c_wass_loss: -89.7882 - g_loss: -4.9814
# Epoch 3314/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.2419 - c_loss: -65.9894 - c_wass_loss: -88.4085 - g_loss: -5.9391
# Epoch 3315/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 4.0578 - c_loss: -48.8530 - c_wass_loss: -89.4308 - g_loss: 0.3512
# Epoch 3316/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - c_gp: 2.9958 - c_loss: -60.7231 - c_wass_loss: -90.6808 - g_loss: -23.4940
# Epoch 3317/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.6055 - c_loss: -62.6267 - c_wass_loss: -88.6817 - g_loss: 5.2460
# Epoch 3318/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 4.7225 - c_loss: -53.0850 - c_wass_loss: -100.3102 - g_loss: 26.3426
# Epoch 3319/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.4651 - c_loss: -63.5908 - c_wass_loss: -98.2421 - g_loss: 7.1220
# Epoch 3320/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.5614 - c_loss: -63.4333 - c_wass_loss: -99.0476 - g_loss: 11.6336
# Epoch 3321/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 546ms/step - c_gp: 3.4695 - c_loss: -68.3513 - c_wass_loss: -103.0460 - g_loss: 2.8840
# Epoch 3322/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.2497 - c_loss: -62.2104 - c_wass_loss: -94.7076 - g_loss: -1.2455
# Epoch 3323/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.8865 - c_loss: -62.3504 - c_wass_loss: -91.2153 - g_loss: -6.9642
# Epoch 3324/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.0117 - c_loss: -61.3471 - c_wass_loss: -91.4639 - g_loss: 37.1160
# Epoch 3325/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.5350 - c_loss: -58.9426 - c_wass_loss: -94.2927 - g_loss: 9.9048
# Epoch 3326/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.3413 - c_loss: -59.3877 - c_wass_loss: -92.8011 - g_loss: 16.2653
# Epoch 3327/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.2737 - c_loss: -65.6338 - c_wass_loss: -98.3711 - g_loss: 15.9432
# Epoch 3328/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.8401 - c_loss: -62.8657 - c_wass_loss: -101.2665 - g_loss: -6.7431
# Epoch 3329/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.4360 - c_loss: -55.2648 - c_wass_loss: -89.6246 - g_loss: 7.3905
# Epoch 3330/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.7722 - c_loss: -60.3926 - c_wass_loss: -98.1150 - g_loss: 0.9147
# Epoch 3331/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 3.3351 - c_loss: -58.2112 - c_wass_loss: -91.5621 - g_loss: -4.7819
# Epoch 3332/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.7576 - c_loss: -57.7987 - c_wass_loss: -85.3742 - g_loss: -7.1190
# Epoch 3333/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 3.6335 - c_loss: -61.2886 - c_wass_loss: -97.6235 - g_loss: -5.9840
# Epoch 3334/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 4.1599 - c_loss: -53.9165 - c_wass_loss: -95.5153 - g_loss: -3.6276
# Epoch 3335/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 4.2778 - c_loss: -54.6040 - c_wass_loss: -97.3821 - g_loss: -3.0431
# Epoch 3336/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 2.9136 - c_loss: -65.6523 - c_wass_loss: -94.7882 - g_loss: 25.7220
# Epoch 3337/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9086 - c_loss: -58.1319 - c_wass_loss: -87.2178 - g_loss: 7.9743
# Epoch 3338/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.3947 - c_loss: -69.7051 - c_wass_loss: -93.6525 - g_loss: 10.7175
# Epoch 3339/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.9208 - c_loss: -66.2426 - c_wass_loss: -95.4510 - g_loss: 13.4412
# Epoch 3340/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.9724 - c_loss: -58.0725 - c_wass_loss: -97.7963 - g_loss: -27.3822
# Epoch 3341/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.7617 - c_loss: -58.3352 - c_wass_loss: -85.9518 - g_loss: -7.2871
# Epoch 3342/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 2.9859 - c_loss: -55.7306 - c_wass_loss: -85.5899 - g_loss: 25.6164
# Epoch 3343/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9053 - c_loss: -59.7854 - c_wass_loss: -88.8384 - g_loss: -0.6877
# Epoch 3344/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.6340 - c_loss: -56.0373 - c_wass_loss: -102.3777 - g_loss: 1.2696
# Epoch 3345/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 4.0044 - c_loss: -58.0218 - c_wass_loss: -98.0663 - g_loss: 12.8714
# Epoch 3346/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 4.2015 - c_loss: -60.8240 - c_wass_loss: -102.8387 - g_loss: 13.9635
# Epoch 3347/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.2279 - c_loss: -64.6461 - c_wass_loss: -96.9248 - g_loss: -19.1011
# Epoch 3348/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.5627 - c_loss: -71.5817 - c_wass_loss: -107.2086 - g_loss: 19.9544
# Epoch 3349/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.2705 - c_loss: -58.9574 - c_wass_loss: -91.6619 - g_loss: -1.2918
# Epoch 3350/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.1464 - c_loss: -60.9523 - c_wass_loss: -92.4168 - g_loss: -22.0366
# Epoch 3351/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.0835 - c_loss: -53.0959 - c_wass_loss: -83.9306 - g_loss: -14.8777
# Epoch 3352/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.4542 - c_loss: -62.6099 - c_wass_loss: -87.1517 - g_loss: -17.6260
# Epoch 3353/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 4.0648 - c_loss: -61.6710 - c_wass_loss: -102.3192 - g_loss: -0.8057
# Epoch 3354/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.2376 - c_loss: -62.6444 - c_wass_loss: -95.0202 - g_loss: 7.0859
# Epoch 3355/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.7504 - c_loss: -59.3331 - c_wass_loss: -96.8375 - g_loss: -10.6476
# Epoch 3356/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.3271 - c_loss: -63.6087 - c_wass_loss: -96.8793 - g_loss: -16.8370
# Epoch 3357/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 2.8284 - c_loss: -63.7347 - c_wass_loss: -92.0191 - g_loss: -29.3336
# Epoch 3358/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 3.0906 - c_loss: -61.5632 - c_wass_loss: -92.4693 - g_loss: 5.4931
# Epoch 3359/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.2800 - c_loss: -54.3284 - c_wass_loss: -97.1287 - g_loss: -3.0322
# Epoch 3360/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 541ms/step - c_gp: 3.5515 - c_loss: -59.8627 - c_wass_loss: -95.3780 - g_loss: 3.0543
# Epoch 3361/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 3.0874 - c_loss: -55.2200 - c_wass_loss: -86.0942 - g_loss: -4.8622
# Epoch 3362/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.1793 - c_loss: -60.8680 - c_wass_loss: -102.6610 - g_loss: -9.7521
# Epoch 3363/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 2.8023 - c_loss: -54.9127 - c_wass_loss: -82.9360 - g_loss: 0.4740
# Epoch 3364/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.1672 - c_loss: -60.6593 - c_wass_loss: -92.3312 - g_loss: -6.9440
# Epoch 3365/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.7456 - c_loss: -65.4889 - c_wass_loss: -92.9450 - g_loss: -16.4447
# Epoch 3366/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 3.7830 - c_loss: -58.6507 - c_wass_loss: -96.4809 - g_loss: -4.5041
# Epoch 3367/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.7239 - c_loss: -61.1379 - c_wass_loss: -98.3767 - g_loss: 18.0023
# Epoch 3368/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.8295 - c_loss: -60.5342 - c_wass_loss: -98.8289 - g_loss: 7.2458
# Epoch 3369/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.2532 - c_loss: -61.0559 - c_wass_loss: -93.5881 - g_loss: 16.6094
# Epoch 3370/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 619ms/step - c_gp: 3.8317 - c_loss: -59.9371 - c_wass_loss: -98.2543 - g_loss: -11.2560
# Epoch 3371/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.0138 - c_loss: -63.6234 - c_wass_loss: -93.7617 - g_loss: -11.3156
# Epoch 3372/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 505ms/step - c_gp: 2.9058 - c_loss: -61.1732 - c_wass_loss: -90.2307 - g_loss: -7.5979
# Epoch 3373/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1201 - c_loss: -58.6475 - c_wass_loss: -89.8481 - g_loss: 6.1112
# Epoch 3374/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1003 - c_loss: -61.3346 - c_wass_loss: -92.3373 - g_loss: -5.4456
# Epoch 3375/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 523ms/step - c_gp: 3.0205 - c_loss: -60.6856 - c_wass_loss: -90.8903 - g_loss: -4.0421
# Epoch 3376/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 4.2035 - c_loss: -56.0177 - c_wass_loss: -98.0531 - g_loss: 18.6414
# Epoch 3377/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.0460 - c_loss: -59.9314 - c_wass_loss: -90.3917 - g_loss: 1.3736
# Epoch 3378/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - c_gp: 2.9635 - c_loss: -63.4028 - c_wass_loss: -93.0379 - g_loss: -10.1969
# Epoch 3379/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.0851 - c_loss: -54.5010 - c_wass_loss: -95.3522 - g_loss: -3.5860
# Epoch 3380/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.3137 - c_loss: -61.1834 - c_wass_loss: -94.3208 - g_loss: -33.0508
# Epoch 3381/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 3.1796 - c_loss: -59.2497 - c_wass_loss: -91.0456 - g_loss: -3.6398
# Epoch 3382/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 4.2055 - c_loss: -61.4443 - c_wass_loss: -103.4994 - g_loss: -10.5204
# Epoch 3383/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.7782 - c_loss: -60.1780 - c_wass_loss: -87.9604 - g_loss: 7.6764
# Epoch 3384/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 2.7964 - c_loss: -61.8588 - c_wass_loss: -89.8233 - g_loss: 40.4913
# Epoch 3385/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.9329 - c_loss: -60.9365 - c_wass_loss: -90.2658 - g_loss: -8.4747
# Epoch 3386/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - c_gp: 3.2536 - c_loss: -63.1750 - c_wass_loss: -95.7108 - g_loss: -1.2988
# Epoch 3387/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.3436 - c_loss: -56.6271 - c_wass_loss: -90.0627 - g_loss: -16.0519
# Epoch 3388/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 2.8635 - c_loss: -59.7607 - c_wass_loss: -88.3952 - g_loss: -1.4408
# Epoch 3389/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 4.1602 - c_loss: -55.7928 - c_wass_loss: -97.3948 - g_loss: -8.5982
# Epoch 3390/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.5756 - c_loss: -53.4864 - c_wass_loss: -89.2422 - g_loss: -5.4750
# Epoch 3391/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.7318 - c_loss: -60.2983 - c_wass_loss: -97.6159 - g_loss: -4.2909
# Epoch 3392/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.4938 - c_loss: -64.1598 - c_wass_loss: -89.0974 - g_loss: -21.8850
# Epoch 3393/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.7119 - c_loss: -64.5610 - c_wass_loss: -101.6802 - g_loss: -10.3854
# Epoch 3394/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.2957 - c_loss: -59.2678 - c_wass_loss: -102.2245 - g_loss: 3.3212
# Epoch 3395/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.1639 - c_loss: -57.7272 - c_wass_loss: -89.3665 - g_loss: -37.3736
# Epoch 3396/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 2.4102 - c_loss: -59.6072 - c_wass_loss: -83.7096 - g_loss: -31.9497
# Epoch 3397/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.7354 - c_loss: -60.7119 - c_wass_loss: -98.0663 - g_loss: -6.7719
# Epoch 3398/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.9101 - c_loss: -69.2812 - c_wass_loss: -98.3818 - g_loss: -12.0338
# Epoch 3399/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.9736 - c_loss: -63.0530 - c_wass_loss: -92.7895 - g_loss: -0.1123
# Epoch 3400/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.6017 - c_loss: -61.7823 - c_wass_loss: -87.7994 - g_loss: -22.9792
# Epoch 3401/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.4747 - c_loss: -61.1490 - c_wass_loss: -95.8962 - g_loss: -12.0587
# Epoch 3402/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.4518 - c_loss: -61.5661 - c_wass_loss: -96.0843 - g_loss: 0.8883
# Epoch 3403/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.7069 - c_loss: -63.9834 - c_wass_loss: -91.0527 - g_loss: 0.4533
# Epoch 3404/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.4060 - c_loss: -56.1716 - c_wass_loss: -90.2319 - g_loss: 1.2144
# Epoch 3405/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 533ms/step - c_gp: 3.4449 - c_loss: -57.4082 - c_wass_loss: -91.8569 - g_loss: 4.4644
# Epoch 3406/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.0013 - c_loss: -57.6264 - c_wass_loss: -97.6392 - g_loss: 2.2545
# Epoch 3407/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 3.4772 - c_loss: -59.2151 - c_wass_loss: -93.9870 - g_loss: -1.3755
# Epoch 3408/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.9331 - c_loss: -61.5497 - c_wass_loss: -90.8802 - g_loss: 3.1360
# Epoch 3409/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.3186 - c_loss: -62.4665 - c_wass_loss: -95.6522 - g_loss: -7.7168
# Epoch 3410/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.6695 - c_loss: -62.1905 - c_wass_loss: -88.8858 - g_loss: -7.6539
# Epoch 3411/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.9222 - c_loss: -60.1230 - c_wass_loss: -99.3448 - g_loss: 1.7691
# Epoch 3412/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.2316 - c_loss: -63.5556 - c_wass_loss: -95.8713 - g_loss: -12.2292
# Epoch 3413/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.8907 - c_loss: -57.2442 - c_wass_loss: -86.1508 - g_loss: -22.6672
# Epoch 3414/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.5040 - c_loss: -63.8679 - c_wass_loss: -88.9075 - g_loss: -19.2050
# Epoch 3415/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.9690 - c_loss: -59.9364 - c_wass_loss: -89.6265 - g_loss: -10.0899
# Epoch 3416/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 5.4569 - c_loss: -49.2750 - c_wass_loss: -103.8437 - g_loss: -0.6123
# Epoch 3417/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.0615 - c_loss: -58.5060 - c_wass_loss: -79.1210 - g_loss: -8.1414
# Epoch 3418/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.2895 - c_loss: -56.7650 - c_wass_loss: -89.6604 - g_loss: -5.2750
# Epoch 3419/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.3644 - c_loss: -58.7064 - c_wass_loss: -92.3500 - g_loss: -23.0756
# Epoch 3420/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 536ms/step - c_gp: 3.2803 - c_loss: -61.0526 - c_wass_loss: -93.8552 - g_loss: -3.1090
# Epoch 3421/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.9964 - c_loss: -63.1214 - c_wass_loss: -93.0857 - g_loss: -17.0336
# Epoch 3422/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.0562 - c_loss: -62.6154 - c_wass_loss: -93.1776 - g_loss: -11.1075
# Epoch 3423/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.1658 - c_loss: -58.1672 - c_wass_loss: -89.8250 - g_loss: -11.7752
# Epoch 3424/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 4.4416 - c_loss: -57.4621 - c_wass_loss: -101.8786 - g_loss: -18.5897
# Epoch 3425/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.9360 - c_loss: -60.6080 - c_wass_loss: -89.9681 - g_loss: 12.4395
# Epoch 3426/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.6111 - c_loss: -61.3720 - c_wass_loss: -97.4828 - g_loss: 27.1126
# Epoch 3427/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.3417 - c_loss: -59.5882 - c_wass_loss: -93.0048 - g_loss: 18.5257
# Epoch 3428/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 6.2656 - c_loss: -37.4522 - c_wass_loss: -100.1084 - g_loss: 22.3119
# Epoch 3429/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 548ms/step - c_gp: 3.8954 - c_loss: -53.1382 - c_wass_loss: -92.0919 - g_loss: 20.4957
# Epoch 3430/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.5964 - c_loss: -59.3436 - c_wass_loss: -85.3081 - g_loss: -10.7978
# Epoch 3431/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.7253 - c_loss: -61.1999 - c_wass_loss: -88.4526 - g_loss: -1.3038
# Epoch 3432/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 2.8203 - c_loss: -57.4247 - c_wass_loss: -85.6277 - g_loss: 1.5490
# Epoch 3433/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.3985 - c_loss: -65.6361 - c_wass_loss: -99.6208 - g_loss: -8.6266
# Epoch 3434/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 4.4204 - c_loss: -51.0091 - c_wass_loss: -95.2129 - g_loss: -22.4175
# Epoch 3435/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 547ms/step - c_gp: 2.4909 - c_loss: -61.0908 - c_wass_loss: -85.9998 - g_loss: -6.0395
# Epoch 3436/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.1159 - c_loss: -63.1938 - c_wass_loss: -94.3529 - g_loss: 12.5901
# Epoch 3437/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.4297 - c_loss: -62.7340 - c_wass_loss: -97.0310 - g_loss: -39.4106
# Epoch 3438/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.1856 - c_loss: -57.6127 - c_wass_loss: -89.4687 - g_loss: -5.9323
# Epoch 3439/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.3392 - c_loss: -59.3625 - c_wass_loss: -92.7541 - g_loss: 1.3798
# Epoch 3440/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 503ms/step - c_gp: 2.8781 - c_loss: -59.4143 - c_wass_loss: -88.1957 - g_loss: -20.7794
# Epoch 3441/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.6181 - c_loss: -57.4652 - c_wass_loss: -93.6465 - g_loss: -19.9808
# Epoch 3442/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.4798 - c_loss: -62.4448 - c_wass_loss: -97.2425 - g_loss: -12.4509
# Epoch 3443/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.5092 - c_loss: -63.0027 - c_wass_loss: -88.0943 - g_loss: -14.7796
# Epoch 3444/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.3394 - c_loss: -57.1968 - c_wass_loss: -90.5908 - g_loss: -2.0595
# Epoch 3445/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.3446 - c_loss: -55.7382 - c_wass_loss: -89.1846 - g_loss: -26.8298
# Epoch 3446/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.1933 - c_loss: -58.9998 - c_wass_loss: -90.9325 - g_loss: 0.8494
# Epoch 3447/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.0452 - c_loss: -64.6081 - c_wass_loss: -95.0604 - g_loss: -9.6418
# Epoch 3448/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 3.1633 - c_loss: -55.8114 - c_wass_loss: -87.4442 - g_loss: -18.9888
# Epoch 3449/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1429 - c_loss: -61.2706 - c_wass_loss: -92.7001 - g_loss: -24.1844
# Epoch 3450/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 547ms/step - c_gp: 3.1314 - c_loss: -58.7315 - c_wass_loss: -90.0459 - g_loss: -10.6328
# Epoch 3451/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.1782 - c_loss: -53.2116 - c_wass_loss: -84.9940 - g_loss: 12.6475
# Epoch 3452/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.7170 - c_loss: -47.6718 - c_wass_loss: -94.8413 - g_loss: 7.4849
# Epoch 3453/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 2.0634 - c_loss: -59.4085 - c_wass_loss: -80.0423 - g_loss: 11.9880
# Epoch 3454/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 3.3152 - c_loss: -60.2178 - c_wass_loss: -93.3694 - g_loss: 17.2585
# Epoch 3455/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.6751 - c_loss: -54.8314 - c_wass_loss: -91.5828 - g_loss: -18.9602
# Epoch 3456/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.9301 - c_loss: -58.5718 - c_wass_loss: -97.8729 - g_loss: -0.5074
# Epoch 3457/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.8732 - c_loss: -53.1140 - c_wass_loss: -91.8457 - g_loss: 7.9483
# Epoch 3458/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.2260 - c_loss: -60.9193 - c_wass_loss: -93.1795 - g_loss: -4.9937
# Epoch 3459/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.8438 - c_loss: -56.1316 - c_wass_loss: -84.5696 - g_loss: 14.5749
# Epoch 3460/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.0799 - c_loss: -59.7905 - c_wass_loss: -90.5892 - g_loss: -9.2255
# Epoch 3461/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.8753 - c_loss: -60.7756 - c_wass_loss: -109.5281 - g_loss: -11.2862
# Epoch 3462/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.2717 - c_loss: -62.5522 - c_wass_loss: -95.2694 - g_loss: -1.3013
# Epoch 3463/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.3392 - c_loss: -57.4024 - c_wass_loss: -90.7947 - g_loss: -9.5349
# Epoch 3464/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.9248 - c_loss: -59.4062 - c_wass_loss: -98.6539 - g_loss: -0.1138
# Epoch 3465/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 3.1715 - c_loss: -61.5722 - c_wass_loss: -93.2874 - g_loss: 19.7551
# Epoch 3466/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.3677 - c_loss: -53.6722 - c_wass_loss: -97.3497 - g_loss: 3.7362
# Epoch 3467/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.1483 - c_loss: -60.6099 - c_wass_loss: -92.0928 - g_loss: 20.9553
# Epoch 3468/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 541ms/step - c_gp: 2.9691 - c_loss: -59.2082 - c_wass_loss: -88.8993 - g_loss: 23.8480
# Epoch 3469/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.4769 - c_loss: -55.4560 - c_wass_loss: -100.2253 - g_loss: 19.8489
# Epoch 3470/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.0719 - c_loss: -59.7006 - c_wass_loss: -90.4191 - g_loss: 1.5030
# Epoch 3471/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.7546 - c_loss: -55.9723 - c_wass_loss: -93.5182 - g_loss: 9.6942
# Epoch 3472/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9588 - c_loss: -64.6186 - c_wass_loss: -94.2069 - g_loss: -8.7620
# Epoch 3473/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 2.8350 - c_loss: -59.2118 - c_wass_loss: -87.5616 - g_loss: 11.9404
# Epoch 3474/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 2.8852 - c_loss: -57.5715 - c_wass_loss: -86.4236 - g_loss: 15.8645
# Epoch 3475/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.5539 - c_loss: -54.8968 - c_wass_loss: -90.4359 - g_loss: -13.6504
# Epoch 3476/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.6827 - c_loss: -67.6493 - c_wass_loss: -104.4759 - g_loss: -1.1720
# Epoch 3477/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.1593 - c_loss: -59.7679 - c_wass_loss: -91.3612 - g_loss: 20.3114
# Epoch 3478/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.1241 - c_loss: -59.9948 - c_wass_loss: -101.2361 - g_loss: 2.9383
# Epoch 3479/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.9044 - c_loss: -56.9281 - c_wass_loss: -95.9723 - g_loss: -2.9921
# Epoch 3480/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 547ms/step - c_gp: 3.1648 - c_loss: -55.9749 - c_wass_loss: -87.6227 - g_loss: 8.1226
# Epoch 3481/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.6061 - c_loss: -64.4833 - c_wass_loss: -90.5441 - g_loss: 4.8208
# Epoch 3482/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9416 - c_loss: -67.2229 - c_wass_loss: -96.6392 - g_loss: -0.6928
# Epoch 3483/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 3.0639 - c_loss: -67.5443 - c_wass_loss: -98.1835 - g_loss: -5.3359
# Epoch 3484/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.2749 - c_loss: -59.3304 - c_wass_loss: -92.0795 - g_loss: -13.1689
# Epoch 3485/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5225 - c_loss: -63.1574 - c_wass_loss: -88.3823 - g_loss: -18.5996
# Epoch 3486/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 4.1630 - c_loss: -50.7326 - c_wass_loss: -92.3626 - g_loss: 7.2330
# Epoch 3487/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - c_gp: 2.9225 - c_loss: -59.2459 - c_wass_loss: -88.4711 - g_loss: -17.7233
# Epoch 3488/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.2024 - c_loss: -57.5970 - c_wass_loss: -89.6207 - g_loss: 11.6187
# Epoch 3489/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.2599 - c_loss: -56.1665 - c_wass_loss: -88.7659 - g_loss: 8.9625
# Epoch 3490/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5882 - c_loss: -66.6797 - c_wass_loss: -92.5612 - g_loss: -2.4000
# Epoch 3491/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.9772 - c_loss: -64.5022 - c_wass_loss: -94.2745 - g_loss: -19.6911
# Epoch 3492/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 4.8056 - c_loss: -52.1117 - c_wass_loss: -100.1678 - g_loss: -10.2240
# Epoch 3493/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.6072 - c_loss: -54.8105 - c_wass_loss: -90.8825 - g_loss: -10.4028
# Epoch 3494/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9699 - c_loss: -62.4511 - c_wass_loss: -92.1500 - g_loss: 16.4548
# Epoch 3495/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 3.6515 - c_loss: -51.6917 - c_wass_loss: -88.2065 - g_loss: 1.7452
# Epoch 3496/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.1442 - c_loss: -53.4618 - c_wass_loss: -84.9037 - g_loss: -5.7219
# Epoch 3497/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.7833 - c_loss: -60.7669 - c_wass_loss: -98.5998 - g_loss: 2.8416
# Epoch 3498/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.4801 - c_loss: -57.8405 - c_wass_loss: -92.6415 - g_loss: -10.1521
# Epoch 3499/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.2904 - c_loss: -60.9848 - c_wass_loss: -93.8884 - g_loss: -17.0375
# Epoch 3500/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 2.6892 - c_loss: -68.4275 - c_wass_loss: -95.3191 - g_loss: 6.4751
# Epoch 3501/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.5471 - c_loss: -53.8395 - c_wass_loss: -89.3110 - g_loss: 0.3486
# Epoch 3502/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 517ms/step - c_gp: 4.1034 - c_loss: -57.9854 - c_wass_loss: -99.0191 - g_loss: 7.5162
# Epoch 3503/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.4880 - c_loss: -55.3967 - c_wass_loss: -80.2772 - g_loss: -13.0527
# Epoch 3504/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.0542 - c_loss: -66.0152 - c_wass_loss: -96.5572 - g_loss: 14.5102
# Epoch 3505/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.4796 - c_loss: -59.7793 - c_wass_loss: -94.5748 - g_loss: 2.1064
# Epoch 3506/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.2716 - c_loss: -57.1693 - c_wass_loss: -89.8849 - g_loss: -16.6505
# Epoch 3507/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.8244 - c_loss: -51.7068 - c_wass_loss: -89.9509 - g_loss: -12.2712
# Epoch 3508/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 2.5799 - c_loss: -56.2609 - c_wass_loss: -82.0603 - g_loss: -5.6339
# Epoch 3509/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.7400 - c_loss: -58.1631 - c_wass_loss: -95.5634 - g_loss: -2.4244
# Epoch 3510/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 2.7210 - c_loss: -64.7097 - c_wass_loss: -91.9198 - g_loss: -3.8476
# Epoch 3511/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.9240 - c_loss: -59.2973 - c_wass_loss: -98.5369 - g_loss: 16.1116
# Epoch 3512/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.5206 - c_loss: -64.1307 - c_wass_loss: -89.3371 - g_loss: -20.3883
# Epoch 3513/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 4.7523 - c_loss: -50.8814 - c_wass_loss: -98.4043 - g_loss: 2.7804
# Epoch 3514/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.5117 - c_loss: -60.4788 - c_wass_loss: -85.5961 - g_loss: 4.8559
# Epoch 3515/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.4945 - c_loss: -60.4328 - c_wass_loss: -95.3774 - g_loss: 1.1513
# Epoch 3516/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 551ms/step - c_gp: 2.7727 - c_loss: -62.7359 - c_wass_loss: -90.4632 - g_loss: -11.8211
# Epoch 3517/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - c_gp: 2.5297 - c_loss: -58.6438 - c_wass_loss: -83.9406 - g_loss: -21.9727
# Epoch 3518/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.4987 - c_loss: -58.6551 - c_wass_loss: -83.6423 - g_loss: 5.1651
# Epoch 3519/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.7630 - c_loss: -53.4555 - c_wass_loss: -91.0853 - g_loss: -7.2775
# Epoch 3520/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.6402 - c_loss: -64.6699 - c_wass_loss: -91.0717 - g_loss: -16.0476
# Epoch 3521/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5597 - c_loss: -63.2601 - c_wass_loss: -88.8570 - g_loss: 19.6932
# Epoch 3522/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.6511 - c_loss: -57.3738 - c_wass_loss: -83.8849 - g_loss: 4.5034
# Epoch 3523/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - c_gp: 3.1081 - c_loss: -64.3965 - c_wass_loss: -95.4774 - g_loss: -3.6232
# Epoch 3524/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.0835 - c_loss: -65.4383 - c_wass_loss: -96.2732 - g_loss: -14.1930
# Epoch 3525/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 549ms/step - c_gp: 3.1859 - c_loss: -62.6007 - c_wass_loss: -94.4596 - g_loss: 21.2439
# Epoch 3526/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.7517 - c_loss: -56.2133 - c_wass_loss: -93.7304 - g_loss: -3.1309
# Epoch 3527/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.4783 - c_loss: -65.0190 - c_wass_loss: -89.8016 - g_loss: -24.8739
# Epoch 3528/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.9420 - c_loss: -56.2573 - c_wass_loss: -85.6772 - g_loss: 7.2499
# Epoch 3529/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.7713 - c_loss: -58.5134 - c_wass_loss: -96.2261 - g_loss: -18.2872
# Epoch 3530/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.6375 - c_loss: -56.5751 - c_wass_loss: -82.9501 - g_loss: 2.0993
# Epoch 3531/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 550ms/step - c_gp: 4.5418 - c_loss: -58.9627 - c_wass_loss: -104.3802 - g_loss: -25.6317
# Epoch 3532/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.6322 - c_loss: -51.7412 - c_wass_loss: -88.0634 - g_loss: -35.4436
# Epoch 3533/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - c_gp: 2.5140 - c_loss: -61.0990 - c_wass_loss: -86.2385 - g_loss: -27.2305
# Epoch 3534/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.6738 - c_loss: -65.8732 - c_wass_loss: -92.6115 - g_loss: -21.8589
# Epoch 3535/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.8414 - c_loss: -59.6879 - c_wass_loss: -88.1014 - g_loss: -19.6724
# Epoch 3536/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.8625 - c_loss: -64.7287 - c_wass_loss: -93.3533 - g_loss: 0.3916
# Epoch 3537/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.6661 - c_loss: -59.3836 - c_wass_loss: -86.0443 - g_loss: 3.2580
# Epoch 3538/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.9393 - c_loss: -59.3180 - c_wass_loss: -98.7112 - g_loss: -3.0679
# Epoch 3539/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 2.4868 - c_loss: -57.6777 - c_wass_loss: -82.5459 - g_loss: 33.3717
# Epoch 3540/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.9815 - c_loss: -55.5455 - c_wass_loss: -95.3607 - g_loss: 7.0953
# Epoch 3541/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 3.2328 - c_loss: -58.4350 - c_wass_loss: -90.7625 - g_loss: 4.0682
# Epoch 3542/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 3.0380 - c_loss: -55.2626 - c_wass_loss: -85.6430 - g_loss: 13.0204
# Epoch 3543/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.1251 - c_loss: -56.8062 - c_wass_loss: -88.0576 - g_loss: 2.9514
# Epoch 3544/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 509ms/step - c_gp: 3.3570 - c_loss: -66.5975 - c_wass_loss: -100.1672 - g_loss: 0.0173
# Epoch 3545/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.5239 - c_loss: -61.5649 - c_wass_loss: -86.8035 - g_loss: -6.8969
# Epoch 3546/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - c_gp: 3.8479 - c_loss: -52.5573 - c_wass_loss: -91.0362 - g_loss: -10.3451
# Epoch 3547/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 3.6497 - c_loss: -57.0002 - c_wass_loss: -93.4973 - g_loss: 20.5499
# Epoch 3548/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.4893 - c_loss: -64.2574 - c_wass_loss: -99.1508 - g_loss: -2.3192
# Epoch 3549/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 2.7279 - c_loss: -61.2116 - c_wass_loss: -88.4902 - g_loss: 5.7056
# Epoch 3550/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 3.2281 - c_loss: -65.6632 - c_wass_loss: -97.9442 - g_loss: -4.4865
# Epoch 3551/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.7735 - c_loss: -60.4182 - c_wass_loss: -88.1535 - g_loss: 2.4650
# Epoch 3552/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 541ms/step - c_gp: 3.2158 - c_loss: -56.8227 - c_wass_loss: -88.9804 - g_loss: -18.4466
# Epoch 3553/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.0035 - c_loss: -58.2781 - c_wass_loss: -88.3132 - g_loss: -18.6223
# Epoch 3554/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.0703 - c_loss: -59.9255 - c_wass_loss: -90.6281 - g_loss: -18.7286
# Epoch 3555/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 2.7553 - c_loss: -59.3483 - c_wass_loss: -86.9010 - g_loss: -2.9138
# Epoch 3556/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 2.8029 - c_loss: -58.7419 - c_wass_loss: -86.7706 - g_loss: -8.3513
# Epoch 3557/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.7756 - c_loss: -55.7048 - c_wass_loss: -83.4607 - g_loss: -27.6181
# Epoch 3558/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - c_gp: 3.0587 - c_loss: -57.3571 - c_wass_loss: -87.9445 - g_loss: 16.3095
# Epoch 3559/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.2020 - c_loss: -54.7317 - c_wass_loss: -86.7514 - g_loss: -6.3663
# Epoch 3560/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 3.2259 - c_loss: -57.1745 - c_wass_loss: -89.4335 - g_loss: 1.0576
# Epoch 3561/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 2.6733 - c_loss: -64.0301 - c_wass_loss: -90.7635 - g_loss: 12.2810
# Epoch 3562/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 5.0892 - c_loss: -45.5892 - c_wass_loss: -96.4809 - g_loss: 17.6660
# Epoch 3563/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 2.6595 - c_loss: -58.6166 - c_wass_loss: -85.2118 - g_loss: 18.4303
# Epoch 3564/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - c_gp: 3.2583 - c_loss: -58.9641 - c_wass_loss: -91.5470 - g_loss: 28.8521
# Epoch 3565/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.4987 - c_loss: -65.0455 - c_wass_loss: -90.0330 - g_loss: 27.1974
# Epoch 3566/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.2358 - c_loss: -66.1810 - c_wass_loss: -88.5386 - g_loss: 1.9546
# Epoch 3567/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.5009 - c_loss: -52.4719 - c_wass_loss: -87.4810 - g_loss: -19.3998
# Epoch 3568/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.5574 - c_loss: -57.6156 - c_wass_loss: -83.1897 - g_loss: -21.5770
# Epoch 3569/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.8943 - c_loss: -60.1300 - c_wass_loss: -89.0728 - g_loss: 9.9165
# Epoch 3570/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.0267 - c_loss: -58.0149 - c_wass_loss: -88.2823 - g_loss: -3.2770
# Epoch 3571/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.2728 - c_loss: -57.2702 - c_wass_loss: -89.9984 - g_loss: -19.3454
# Epoch 3572/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.8992 - c_loss: -58.1610 - c_wass_loss: -87.1526 - g_loss: -4.0375
# Epoch 3573/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.6874 - c_loss: -55.6228 - c_wass_loss: -82.4968 - g_loss: -11.5054
# Epoch 3574/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 506ms/step - c_gp: 3.0148 - c_loss: -58.8362 - c_wass_loss: -88.9841 - g_loss: -4.1578
# Epoch 3575/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 3.7584 - c_loss: -64.1593 - c_wass_loss: -101.7435 - g_loss: -10.2699
# Epoch 3576/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 546ms/step - c_gp: 2.5523 - c_loss: -60.2852 - c_wass_loss: -85.8085 - g_loss: -4.7731
# Epoch 3577/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.8398 - c_loss: -59.6005 - c_wass_loss: -97.9987 - g_loss: -12.9108
# Epoch 3578/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 3.2507 - c_loss: -48.0968 - c_wass_loss: -80.6038 - g_loss: -17.2344
# Epoch 3579/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 2.9655 - c_loss: -54.8842 - c_wass_loss: -84.5393 - g_loss: 0.6258
# Epoch 3580/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.6076 - c_loss: -65.8744 - c_wass_loss: -91.9502 - g_loss: -14.3382
# Epoch 3581/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5818 - c_loss: -62.2988 - c_wass_loss: -88.1167 - g_loss: -8.8737
# Epoch 3582/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.5843 - c_loss: -57.7908 - c_wass_loss: -93.6341 - g_loss: -17.6817
# Epoch 3583/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.6946 - c_loss: -55.8464 - c_wass_loss: -92.7927 - g_loss: 10.5615
# Epoch 3584/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 4.4200 - c_loss: -53.0893 - c_wass_loss: -97.2893 - g_loss: 27.6270
# Epoch 3585/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 536ms/step - c_gp: 2.3514 - c_loss: -54.0432 - c_wass_loss: -77.5568 - g_loss: -4.8761
# Epoch 3586/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 519ms/step - c_gp: 2.3931 - c_loss: -61.4355 - c_wass_loss: -85.3666 - g_loss: -25.7558
# Epoch 3587/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.0180 - c_loss: -60.9508 - c_wass_loss: -91.1304 - g_loss: -21.4375
# Epoch 3588/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 536ms/step - c_gp: 3.6684 - c_loss: -54.4940 - c_wass_loss: -91.1784 - g_loss: -19.7612
# Epoch 3589/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.6206 - c_loss: -60.5011 - c_wass_loss: -86.7072 - g_loss: -9.7572
# Epoch 3590/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9165 - c_loss: -61.5964 - c_wass_loss: -90.7610 - g_loss: -19.6518
# Epoch 3591/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - c_gp: 3.1930 - c_loss: -61.7681 - c_wass_loss: -93.6977 - g_loss: -14.6026
# Epoch 3592/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 568ms/step - c_gp: 3.7437 - c_loss: -52.0493 - c_wass_loss: -89.4859 - g_loss: -22.6792
# Epoch 3593/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.9219 - c_loss: -53.8594 - c_wass_loss: -93.0785 - g_loss: -9.0611
# Epoch 3594/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 523ms/step - c_gp: 3.2107 - c_loss: -56.3394 - c_wass_loss: -88.4459 - g_loss: -3.5945
# Epoch 3595/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.1091 - c_loss: -57.4987 - c_wass_loss: -88.5894 - g_loss: -6.0784
# Epoch 3596/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.1884 - c_loss: -55.1202 - c_wass_loss: -87.0044 - g_loss: 11.1561
# Epoch 3597/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 526ms/step - c_gp: 3.0915 - c_loss: -61.2757 - c_wass_loss: -92.1904 - g_loss: 17.7545
# Epoch 3598/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 4.4314 - c_loss: -52.9049 - c_wass_loss: -97.2190 - g_loss: 6.8743
# Epoch 3599/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4882 - c_loss: -64.6908 - c_wass_loss: -89.5732 - g_loss: 12.2311
# Epoch 3600/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - c_gp: 3.4442 - c_loss: -48.8517 - c_wass_loss: -83.2939 - g_loss: -19.4255
# Epoch 3601/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.0426 - c_loss: -62.4463 - c_wass_loss: -92.8728 - g_loss: 0.2935
# Epoch 3602/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9223 - c_loss: -61.3499 - c_wass_loss: -90.5725 - g_loss: -11.5126
# Epoch 3603/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 4.5493 - c_loss: -43.4805 - c_wass_loss: -88.9732 - g_loss: -9.1518
# Epoch 3604/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.8693 - c_loss: -50.1629 - c_wass_loss: -78.8558 - g_loss: 7.3396
# Epoch 3605/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.2842 - c_loss: -61.4511 - c_wass_loss: -84.2930 - g_loss: -5.2903
# Epoch 3606/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 2.6279 - c_loss: -59.1746 - c_wass_loss: -85.4532 - g_loss: -23.3781
# Epoch 3607/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.2894 - c_loss: -59.8263 - c_wass_loss: -92.7203 - g_loss: -1.0671
# Epoch 3608/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.9563 - c_loss: -60.9049 - c_wass_loss: -90.4675 - g_loss: -7.0136
# Epoch 3609/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 538ms/step - c_gp: 3.0592 - c_loss: -70.1295 - c_wass_loss: -100.7218 - g_loss: 16.3613
# Epoch 3610/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.8904 - c_loss: -59.8574 - c_wass_loss: -88.7616 - g_loss: -13.3844
# Epoch 3611/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.9025 - c_loss: -59.6893 - c_wass_loss: -88.7144 - g_loss: -9.3111
# Epoch 3612/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 2.4677 - c_loss: -63.0674 - c_wass_loss: -87.7443 - g_loss: -1.1355
# Epoch 3613/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.2400 - c_loss: -60.5325 - c_wass_loss: -92.9322 - g_loss: 8.2037
# Epoch 3614/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.7054 - c_loss: -64.7508 - c_wass_loss: -101.8047 - g_loss: 10.2782
# Epoch 3615/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - c_gp: 3.3863 - c_loss: -54.5527 - c_wass_loss: -88.4152 - g_loss: -10.5132
# Epoch 3616/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.2953 - c_loss: -58.6747 - c_wass_loss: -91.6282 - g_loss: 12.3930
# Epoch 3617/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 5.3460 - c_loss: -52.6812 - c_wass_loss: -106.1410 - g_loss: 11.8476
# Epoch 3618/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 2.7189 - c_loss: -60.7552 - c_wass_loss: -87.9444 - g_loss: -1.5727
# Epoch 3619/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 4.4868 - c_loss: -47.3138 - c_wass_loss: -92.1823 - g_loss: -1.9168
# Epoch 3620/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.2842 - c_loss: -56.3721 - c_wass_loss: -79.2141 - g_loss: -17.6383
# Epoch 3621/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 3.5265 - c_loss: -54.2011 - c_wass_loss: -89.4657 - g_loss: 19.7078
# Epoch 3622/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.2563 - c_loss: -54.7704 - c_wass_loss: -87.3338 - g_loss: 5.3981
# Epoch 3623/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 3.3938 - c_loss: -57.4155 - c_wass_loss: -91.3540 - g_loss: -2.1897
# Epoch 3624/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 837ms/step - c_gp: 3.4730 - c_loss: -57.8765 - c_wass_loss: -92.6068 - g_loss: 2.0367
# Epoch 3625/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 486ms/step - c_gp: 3.4522 - c_loss: -52.8761 - c_wass_loss: -87.3977 - g_loss: -4.9870
# Epoch 3626/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 502ms/step - c_gp: 3.6688 - c_loss: -55.1582 - c_wass_loss: -91.8464 - g_loss: 0.7776
# Epoch 3627/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.5491 - c_loss: -63.3404 - c_wass_loss: -88.8317 - g_loss: -0.7809
# Epoch 3628/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.1270 - c_loss: -62.4909 - c_wass_loss: -93.7606 - g_loss: -1.9783
# Epoch 3629/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 2.9094 - c_loss: -58.9220 - c_wass_loss: -88.0161 - g_loss: 6.3653
# Epoch 3630/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 4.0270 - c_loss: -64.7253 - c_wass_loss: -104.9952 - g_loss: -1.1932
# Epoch 3631/6000
# ...
# Epoch 5645/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 846ms/step - c_gp: 2.3209 - c_loss: -51.4480 - c_wass_loss: -74.6570 - g_loss: -15.9952
# Epoch 5646/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.2861 - c_loss: -46.1485 - c_wass_loss: -69.0093 - g_loss: 1.6526
# Epoch 5647/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 2.5310 - c_loss: -44.2913 - c_wass_loss: -69.6010 - g_loss: -3.3863
# Epoch 5648/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 1.5618 - c_loss: -46.1351 - c_wass_loss: -61.7527 - g_loss: -3.8875
# Epoch 5649/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 851ms/step - c_gp: 2.6256 - c_loss: -43.3060 - c_wass_loss: -69.5620 - g_loss: -18.9707
# Epoch 5650/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4892 - c_loss: -53.6633 - c_wass_loss: -78.5552 - g_loss: -32.0278
# Epoch 5651/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 897ms/step - c_gp: 2.1583 - c_loss: -58.7437 - c_wass_loss: -80.3270 - g_loss: -26.1528
# Epoch 5652/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 2.6124 - c_loss: -43.6056 - c_wass_loss: -69.7300 - g_loss: -16.1614
# Epoch 5653/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.1822 - c_loss: -49.2846 - c_wass_loss: -71.1065 - g_loss: -18.4337
# Epoch 5654/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 2.0299 - c_loss: -48.7028 - c_wass_loss: -69.0023 - g_loss: -19.7338
# Epoch 5655/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 801ms/step - c_gp: 2.1863 - c_loss: -53.9687 - c_wass_loss: -75.8316 - g_loss: -37.6615
# Epoch 5656/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 501ms/step - c_gp: 1.8727 - c_loss: -46.1123 - c_wass_loss: -64.8393 - g_loss: 12.4617
# Epoch 5657/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 2.0519 - c_loss: -52.1744 - c_wass_loss: -72.6934 - g_loss: -15.5458
# Epoch 5658/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step - c_gp: 1.5999 - c_loss: -51.5010 - c_wass_loss: -67.5000 - g_loss: -45.2673
# Epoch 5659/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - c_gp: 2.7055 - c_loss: -47.8509 - c_wass_loss: -74.9064 - g_loss: -26.1921
# Epoch 5660/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 1.8599 - c_loss: -52.2985 - c_wass_loss: -70.8979 - g_loss: -18.1063
# Epoch 5661/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.0649 - c_loss: -54.9169 - c_wass_loss: -75.5662 - g_loss: -40.0135
# Epoch 5662/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 621ms/step - c_gp: 1.9451 - c_loss: -43.5629 - c_wass_loss: -63.0136 - g_loss: -4.8110
# Epoch 5663/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.0587 - c_loss: -46.1657 - c_wass_loss: -66.7525 - g_loss: -19.1436
# Epoch 5664/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.6887 - c_loss: -44.9110 - c_wass_loss: -71.7979 - g_loss: -15.5223
# Epoch 5665/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 584ms/step - c_gp: 2.0262 - c_loss: -45.9789 - c_wass_loss: -66.2407 - g_loss: -9.1360
# Epoch 5666/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.7768 - c_loss: -44.2599 - c_wass_loss: -72.0275 - g_loss: -10.8146
# Epoch 5667/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 2.0764 - c_loss: -53.6609 - c_wass_loss: -74.4246 - g_loss: -22.0330
# Epoch 5668/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 514ms/step - c_gp: 2.5669 - c_loss: -45.6082 - c_wass_loss: -71.2768 - g_loss: -0.8382
# Epoch 5669/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4552 - c_loss: -49.6462 - c_wass_loss: -74.1982 - g_loss: -16.5483
# Epoch 5670/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 608ms/step - c_gp: 1.5482 - c_loss: -50.3225 - c_wass_loss: -65.8041 - g_loss: -20.8221
# Epoch 5671/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 2.3921 - c_loss: -47.3004 - c_wass_loss: -71.2214 - g_loss: -0.7592
# Epoch 5672/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.5193 - c_loss: -46.1118 - c_wass_loss: -71.3053 - g_loss: -10.1795
# Epoch 5673/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 588ms/step - c_gp: 1.9449 - c_loss: -53.1890 - c_wass_loss: -72.6383 - g_loss: 8.6863
# Epoch 5674/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 1.6151 - c_loss: -53.4000 - c_wass_loss: -69.5515 - g_loss: -8.1467
# Epoch 5675/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4568 - c_loss: -46.5141 - c_wass_loss: -71.0821 - g_loss: -5.4000
# Epoch 5676/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 668ms/step - c_gp: 2.6405 - c_loss: -49.0488 - c_wass_loss: -75.4533 - g_loss: -20.4669
# Epoch 5677/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 494ms/step - c_gp: 1.6844 - c_loss: -51.2473 - c_wass_loss: -68.0910 - g_loss: -17.6912
# Epoch 5678/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 610ms/step - c_gp: 2.0513 - c_loss: -49.1865 - c_wass_loss: -69.6997 - g_loss: -26.7235
# Epoch 5679/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.3620 - c_loss: -49.8390 - c_wass_loss: -73.4587 - g_loss: -30.8675
# Epoch 5680/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.5675 - c_loss: -46.1431 - c_wass_loss: -71.8177 - g_loss: -19.7924
# Epoch 5681/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 588ms/step - c_gp: 3.1378 - c_loss: -49.0161 - c_wass_loss: -80.3943 - g_loss: -11.4779
# Epoch 5682/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.0197 - c_loss: -49.8066 - c_wass_loss: -70.0032 - g_loss: -8.4952
# Epoch 5683/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 3.1393 - c_loss: -39.1702 - c_wass_loss: -70.5636 - g_loss: -2.6629
# Epoch 5684/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 613ms/step - c_gp: 1.5074 - c_loss: -45.7771 - c_wass_loss: -60.8515 - g_loss: -3.6596
# Epoch 5685/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.5006 - c_loss: -49.5302 - c_wass_loss: -74.5362 - g_loss: -11.9773
# Epoch 5686/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 2.2394 - c_loss: -46.7781 - c_wass_loss: -69.1719 - g_loss: -31.7147
# Epoch 5687/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 1.9763 - c_loss: -45.3294 - c_wass_loss: -65.0927 - g_loss: -21.1409
# Epoch 5688/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.2900 - c_loss: -45.4610 - c_wass_loss: -68.3609 - g_loss: -5.2059
# Epoch 5689/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 614ms/step - c_gp: 2.0294 - c_loss: -43.9035 - c_wass_loss: -64.1975 - g_loss: 15.0481
# Epoch 5690/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 4.2028 - c_loss: -34.6686 - c_wass_loss: -76.6964 - g_loss: -1.4096
# Epoch 5691/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.2066 - c_loss: -36.7687 - c_wass_loss: -68.8344 - g_loss: -1.5454
# Epoch 5692/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 602ms/step - c_gp: 2.3688 - c_loss: -39.8388 - c_wass_loss: -63.5271 - g_loss: -17.1716
# Epoch 5693/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.2701 - c_loss: -43.2784 - c_wass_loss: -65.9794 - g_loss: -40.1320
# Epoch 5694/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 1.9232 - c_loss: -44.7704 - c_wass_loss: -64.0028 - g_loss: -15.5980
# Epoch 5695/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 858ms/step - c_gp: 2.4666 - c_loss: -48.3444 - c_wass_loss: -73.0103 - g_loss: -0.6945
# Epoch 5696/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.2546 - c_loss: -49.5076 - c_wass_loss: -72.0536 - g_loss: -25.6663
# Epoch 5697/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - c_gp: 2.3323 - c_loss: -48.8183 - c_wass_loss: -72.1418 - g_loss: -19.6148
# Epoch 5698/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 499ms/step - c_gp: 2.1029 - c_loss: -45.8555 - c_wass_loss: -66.8840 - g_loss: -20.2702
# Epoch 5699/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.3829 - c_loss: -49.4698 - c_wass_loss: -73.2984 - g_loss: -38.7455
# Epoch 5700/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - c_gp: 3.1326 - c_loss: -39.9874 - c_wass_loss: -71.3133 - g_loss: -42.0324
# Epoch 5701/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - c_gp: 1.8417 - c_loss: -51.8434 - c_wass_loss: -70.2599 - g_loss: -1.1530
# Epoch 5702/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 501ms/step - c_gp: 2.6155 - c_loss: -53.2030 - c_wass_loss: -79.3582 - g_loss: -17.4606
# Epoch 5703/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 828ms/step - c_gp: 2.0438 - c_loss: -40.5422 - c_wass_loss: -60.9799 - g_loss: -9.0135
# Epoch 5704/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 3.5520 - c_loss: -39.3288 - c_wass_loss: -74.8491 - g_loss: -20.7150
# Epoch 5705/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 877ms/step - c_gp: 2.5156 - c_loss: -43.0587 - c_wass_loss: -68.2151 - g_loss: -44.6811
# Epoch 5706/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.2663 - c_loss: -48.7510 - c_wass_loss: -71.4141 - g_loss: -20.3280
# Epoch 5707/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 506ms/step - c_gp: 2.6931 - c_loss: -39.8993 - c_wass_loss: -66.8306 - g_loss: -17.4279
# Epoch 5708/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - c_gp: 1.9828 - c_loss: -44.7824 - c_wass_loss: -64.6102 - g_loss: -19.4318
# Epoch 5709/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 766ms/step - c_gp: 2.6429 - c_loss: -41.7850 - c_wass_loss: -68.2143 - g_loss: -18.9686
# Epoch 5710/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 1.9042 - c_loss: -54.8578 - c_wass_loss: -73.9002 - g_loss: 7.7830
# Epoch 5711/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - c_gp: 2.1780 - c_loss: -48.7258 - c_wass_loss: -70.5058 - g_loss: 5.5544
# Epoch 5712/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.5641 - c_loss: -50.2977 - c_wass_loss: -75.9385 - g_loss: 0.5928
# Epoch 5713/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 801ms/step - c_gp: 2.4219 - c_loss: -46.0780 - c_wass_loss: -70.2968 - g_loss: -18.9881
# Epoch 5714/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4567 - c_loss: -44.8980 - c_wass_loss: -69.4647 - g_loss: -10.8190
# Epoch 5715/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 843ms/step - c_gp: 1.7672 - c_loss: -43.9600 - c_wass_loss: -61.6325 - g_loss: -19.3882
# Epoch 5716/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.6886 - c_loss: -41.6530 - c_wass_loss: -68.5390 - g_loss: -14.3351
# Epoch 5717/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 572ms/step - c_gp: 2.2022 - c_loss: -56.5199 - c_wass_loss: -78.5420 - g_loss: -30.4503
# Epoch 5718/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - c_gp: 2.9641 - c_loss: -39.2455 - c_wass_loss: -68.8860 - g_loss: -25.7078
# Epoch 5719/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.1569 - c_loss: -46.3297 - c_wass_loss: -67.8984 - g_loss: -57.5064
# Epoch 5720/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 571ms/step - c_gp: 1.9100 - c_loss: -51.7123 - c_wass_loss: -70.8122 - g_loss: -16.8246
# Epoch 5721/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.2691 - c_loss: -50.6264 - c_wass_loss: -73.3176 - g_loss: 14.0046
# Epoch 5722/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.9504 - c_loss: -40.0455 - c_wass_loss: -69.5499 - g_loss: 10.8213
# Epoch 5723/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 577ms/step - c_gp: 2.5430 - c_loss: -41.3957 - c_wass_loss: -66.8258 - g_loss: -24.9539
# Epoch 5724/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.1803 - c_loss: -50.7792 - c_wass_loss: -72.5825 - g_loss: -6.7748
# Epoch 5725/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.5630 - c_loss: -44.1032 - c_wass_loss: -69.7331 - g_loss: -26.7730
# Epoch 5726/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 816ms/step - c_gp: 1.9588 - c_loss: -49.8957 - c_wass_loss: -69.4835 - g_loss: -8.9927
# Epoch 5727/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.7927 - c_loss: -45.2056 - c_wass_loss: -73.1323 - g_loss: -10.3577
# Epoch 5728/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 847ms/step - c_gp: 2.2851 - c_loss: -47.2371 - c_wass_loss: -70.0881 - g_loss: -19.0770
# Epoch 5729/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - c_gp: 2.7328 - c_loss: -44.0430 - c_wass_loss: -71.3706 - g_loss: -10.4966
# Epoch 5730/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - c_gp: 2.0699 - c_loss: -45.2371 - c_wass_loss: -65.9360 - g_loss: -7.8133
# Epoch 5731/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 3.4724 - c_loss: -40.7844 - c_wass_loss: -75.5079 - g_loss: -11.9707
# Epoch 5732/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 496ms/step - c_gp: 2.2588 - c_loss: -42.4423 - c_wass_loss: -65.0305 - g_loss: -6.6616
# Epoch 5733/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 560ms/step - c_gp: 2.6650 - c_loss: -45.8344 - c_wass_loss: -72.4841 - g_loss: 16.7180
# Epoch 5734/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 1.9062 - c_loss: -47.0271 - c_wass_loss: -66.0888 - g_loss: 12.1251
# Epoch 5735/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 3.3477 - c_loss: -44.6166 - c_wass_loss: -78.0939 - g_loss: -16.6727
# Epoch 5736/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 612ms/step - c_gp: 1.6546 - c_loss: -44.3023 - c_wass_loss: -60.8484 - g_loss: -4.9300
# Epoch 5737/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.4215 - c_loss: -49.7777 - c_wass_loss: -73.9929 - g_loss: 2.0908
# Epoch 5738/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 2.3131 - c_loss: -51.4330 - c_wass_loss: -74.5641 - g_loss: -13.9170
# Epoch 5739/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - c_gp: 1.2104 - c_loss: -42.8395 - c_wass_loss: -54.9438 - g_loss: -60.2450
# Epoch 5740/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 496ms/step - c_gp: 1.8086 - c_loss: -49.0048 - c_wass_loss: -67.0907 - g_loss: -38.6628
# Epoch 5741/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 595ms/step - c_gp: 3.5831 - c_loss: -37.7812 - c_wass_loss: -73.6119 - g_loss: -25.7305
# Epoch 5742/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - c_gp: 2.4835 - c_loss: -43.1161 - c_wass_loss: -67.9514 - g_loss: -20.8502
# Epoch 5743/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.0390 - c_loss: -48.2339 - c_wass_loss: -68.6242 - g_loss: -32.2979
# Epoch 5744/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 889ms/step - c_gp: 2.2828 - c_loss: -47.9483 - c_wass_loss: -70.7764 - g_loss: -28.6802
# Epoch 5745/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - c_gp: 2.0864 - c_loss: -48.4315 - c_wass_loss: -69.2958 - g_loss: -21.3074
# Epoch 5746/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 562ms/step - c_gp: 2.7679 - c_loss: -44.1165 - c_wass_loss: -71.7958 - g_loss: -12.3316
# Epoch 5747/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 1.6010 - c_loss: -53.1562 - c_wass_loss: -69.1661 - g_loss: -2.9268
# Epoch 5748/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 495ms/step - c_gp: 2.4469 - c_loss: -48.9972 - c_wass_loss: -73.4661 - g_loss: -13.9208
# Epoch 5749/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 825ms/step - c_gp: 2.0750 - c_loss: -49.9906 - c_wass_loss: -70.7405 - g_loss: -1.6384
# Epoch 5750/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - c_gp: 2.1669 - c_loss: -48.9226 - c_wass_loss: -70.5920 - g_loss: 4.3252
# Epoch 5751/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - c_gp: 2.9289 - c_loss: -45.4187 - c_wass_loss: -74.7076 - g_loss: -29.4356
# Epoch 5752/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - c_gp: 1.9450 - c_loss: -52.8020 - c_wass_loss: -72.2523 - g_loss: -2.4588
# Epoch 5753/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 562ms/step - c_gp: 2.6117 - c_loss: -42.5372 - c_wass_loss: -68.6545 - g_loss: -14.9049
# Epoch 5754/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - c_gp: 2.5254 - c_loss: -50.9766 - c_wass_loss: -76.2306 - g_loss: -12.4364
# Epoch 5755/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.4071 - c_loss: -40.9064 - c_wass_loss: -64.9773 - g_loss: -11.0410
# Epoch 5756/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 595ms/step - c_gp: 2.9276 - c_loss: -44.5218 - c_wass_loss: -73.7978 - g_loss: -35.8223
# Epoch 5757/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - c_gp: 2.2097 - c_loss: -53.0456 - c_wass_loss: -75.1427 - g_loss: -35.6211
# Epoch 5758/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 2.1278 - c_loss: -45.1924 - c_wass_loss: -66.4703 - g_loss: -18.7967
# Epoch 5759/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 498ms/step - c_gp: 2.7383 - c_loss: -45.2969 - c_wass_loss: -72.6799 - g_loss: -17.6440
# Epoch 5760/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 534ms/step - c_gp: 1.9120 - c_loss: -46.4398 - c_wass_loss: -65.5595 - g_loss: -17.0479
# Epoch 5761/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 618ms/step - c_gp: 2.2306 - c_loss: -42.2282 - c_wass_loss: -64.5344 - g_loss: -27.4107
# Epoch 5762/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 493ms/step - c_gp: 1.6659 - c_loss: -46.8891 - c_wass_loss: -63.5485 - g_loss: -12.4795
# Epoch 5763/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 507ms/step - c_gp: 2.3724 - c_loss: -45.3730 - c_wass_loss: -69.0973 - g_loss: -10.1124
# Epoch 5764/6000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 583ms/step - c_gp: 3.1261 - c_loss: -41.4760 - c_wass_loss: -72.7372 - g_loss: -13.4198
# Epoch 5765/6000
# 3/8 ━━━━━━━━━━━━━━━━━━━━ 2s 405ms/step - c_gp: 2.8210 - c_loss: -37.3759 - c_wass_loss: -65.5856 - g_loss: -37.1727

# %% [markdown]
# # Generate new scores

# %%
num_scores = 1
chords_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
style_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
melody_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
groove_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
random_latent_vectors = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music = generator(random_latent_vectors)
generated_music = generated_music.numpy()

draw_score(generated_music, 0)
notes_to_midi(
    generated_music, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi"
)

# %% [markdown]
# ## Changing Chord Noise

# %%
chords_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_2 = [
    chords_random_latent_vectors_2,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_2 = generator(random_latent_vectors_2)
generated_music_2 = generated_music_2.numpy()
draw_score(generated_music_2, 0)
notes_to_midi(
    generated_music_2,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_chords_changed",
)

# %% [markdown]
# # Changing Style Noise

# %%
style_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_3 = [
    chords_random_latent_vectors,
    style_random_latent_vectors_2,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_3 = generator(random_latent_vectors_3)
generated_music_3 = generated_music_3.numpy()
draw_score(generated_music_3, 0)
notes_to_midi(
    generated_music_3,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_style_changed",
)

# %% [markdown]
# ## Changing Melody Noise

# %%
melody_random_latent_vectors_2 = np.copy(melody_random_latent_vectors)
melody_random_latent_vectors_2[:, 0, :] = np.random.normal(
    size=(num_scores, Z_DIM)
)

random_latent_vectors_4 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors_2,
    groove_random_latent_vectors,
]
generated_music_4 = generator(random_latent_vectors_4)
generated_music_4 = generated_music_4.numpy()
draw_score(generated_music_4, 0)
notes_to_midi(
    generated_music_4,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_melody_changed",
)

# %% [markdown]
# ## Changing groove noise

# %%
groove_random_latent_vectors_2 = np.copy(groove_random_latent_vectors)
groove_random_latent_vectors_2[:, -1, :] = np.random.normal(
    size=(num_scores, Z_DIM)
)

random_latent_vectors_5 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors_2,
]
generated_music_5 = generator(random_latent_vectors_5)
generated_music_5 = generated_music_5.numpy()
draw_score(generated_music_5, 0)
notes_to_midi(
    generated_music_5,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_groove_changed",
)
