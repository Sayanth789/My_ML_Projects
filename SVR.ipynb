# %% [markdown]
# ## Support Vector Regression (SVR) using Linear and Non-Linear Kernels in Scikit-Learn

# %% [markdown]
# Support vector regression (SVR) is a type of support vector machine (SVM) that is used for regression tasks. It tries to find a function that best predicts the continuous output value for a given input value.
#
# SVR can use both linear and non-linear kernels. A linear kernel is a simple dot product between two input vectors, while a non-linear kernel is a more complex function that can capture more intricate patterns in the data. The choice of kernel depends on the data's characteristics and the task's complexity.
#
# * SVR : Is a type of `SVM` and is a supervised learning algorithm that can be used for classification or regression tasks. SVMs try to find the hyperplane in a high-dimensional space that maximally seperates different classes or output values.
#
# * Kernels : SVR can use different types of kernels, which are functions that determine the similarity between input vectors. A linear kernel is a simple dot product between two input vectors, while a non-linear kernel is a more complex function that can capture more intricate patterns in the data. The choice of kernel depends on the data's characteristics and the task's complexity.
#
# * Hyperparameters: SVR has several hyperparameters that one can adjust to control the behaviour of the model.

# %% [markdown]
# ### Fitting SVMR model on the Sine Curve data using the Linear Kenrel
# First we try to achieve some baseline results using the Linear kernel on a non-liner dataset and we try to obesrve up to what extent it can be fitten by the model.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# generate synthetic data
X = np.sort(5 * np.random.rand(40, 1),
            axis=0)

y = np.sin(X).ravel()

#  add some noise to the data
y[::5] += 3 * (0.5 - np.random.rand(8))

# create an SVR model with a linear kernel
svr = SVR(kernel='linear')

# train the model on the data
svr.fit(X, y)

# make predictions on the data
y_pred = svr.predict(X)

# plot the predicted values against the true values
plt.scatter(X, y, color='darkorange',
            label='data')
plt.plot(X, y_pred, color='cornflowerblue',
         lable='predictions')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2174697238.py in <cell line: 0>()
#      24 plt.scatter(X, y, color='darkorange',
#      25             label='data')
# ---> 26 plt.plot(X, y_pred, color='cornflowerblue',
#      27          lable='predictions')
#      28 plt.legend()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
# ...

# %% [markdown]
# ## Fitting an SVR Model on the Sine Curve data using the Polynomial kernel
#
# Now we fit a Suport vector Regression model using a polynomial kernel. This will be a little better than SVR model with a linear kernel

# %%
import numpy as np
import matplotlib.pyplot as ply
from sklearn.svm import SVR

# generate synthetic data
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.sin(X).ravel()

# add some noise to the data
y[::5] += 3  * (0.5 - np.random.rand(8))

# create an SVR model with a linear kernel
avr = SVR(kernel='ploy')

# train the model on the data
svr.fit(X, y)

# make prediction an the data
y_pred = svr.predict(X)

# Plot the predicted values against the true values
plt.scatter(X,y, color='darkorange', label='data')
plt.plot(X, y_pred, color='cornflowerblue', label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ## Fitting an SVR Model on the Sine Curve data using RBF Kernel
# Now we will fit a Support vector Regression model using an RBF(Radial Basis Function) kernel. This will help us to achieve probably the best results as the RBF kernel is one of the best kernels which helps us to introduce non-linearity in our model.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR


X = np.sort(5 * np.random.rand(40, 1),
    axis=0)
y = np.sin(X).ravel()


# adding some noise to the data
y[::5] += 3 * (0.5 - np.random.rand(8))

# create an SVR model with a rbf kernel
svr = SVR(kernel='rbf')

# train the model on the data
svr.fit(X, y)


# making predictions on the data
y_pred = svr.predict(X)


# plotting the predicted values against the true values
plt.scatter(X, y, color='darkorange',
            label='data')

plt.plot(X, y_pred, color='cornflowerblue',
         label='predictions')

plt.legend()
plt.show()
