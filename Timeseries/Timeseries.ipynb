# %% [markdown]
# # Data setup
# * setup time series data for this module
# * visualize the data
#
# The data in this example is taken from the GEFCom2014 forecasting competition1. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014.

# %%
import os
import matplotlib.pyplot as plt
from common.utils import load_data

# %matplotlib inline

# %% [markdown]
# Load the data from csv into Pandas DF.

# %%
data_dir = './data'
energy = load_data(data_dir)[['load']]
energy.head()
# Out:
# /content/common/utils.py:18: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(
#                        load
# 2012-01-01 00:00:00  2698.0
# 2012-01-01 01:00:00  2558.0
# 2012-01-01 02:00:00  2444.0
# 2012-01-01 03:00:00  2402.0
# 2012-01-01 04:00:00  2403.0

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
energy['2014-07-01':'2014-07-07'].plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
